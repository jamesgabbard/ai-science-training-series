# %% [markdown]
# # CIFAR-10 dataset classification with MLPs
#
# Author: Tanwi Mallick, adapting codes from Bethany Lusch, Prasanna Balprakash, Corey Adams, and Kyle Felker
#
# In this notebook, we'll continue the CIFAR-10 problem but using the Keras API (as included in the TensorFlow library)
#
# First, the needed imports.

# %%
# %matplotlib inline

import tensorflow as tf

import numpy
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## CIFAR-10 data set
#
# Again we'll load the cifar10 data set. CIFAR-10 dataset contains 32x32 color images from 10 classes: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. If you haven't downloaded it already, it could take a while.
#
# <img src="images/CIFAR-10.png"  align="left"/>

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype(numpy.float32)
x_test  = x_test.astype(numpy.float32)

x_train /= 255.
x_test  /= 255.

y_train = y_train.astype(numpy.int32)
y_test  = y_test.astype(numpy.int32)

print()
print('CIFAR-10 data loaded: train:',len(x_train),'test:',len(x_test))
print('X_train:', x_train.shape)
print('y_train:', y_train.shape)
# Out:
# CIFAR-10 data loaded: train: 50000 test: 10000
# X_train: (50000, 32, 32, 3)
# y_train: (50000, 1)

# %% [markdown]
# ### Download the dataset and load

# %%
# !pip install image-dataset-loader
# !wget https://s3.amazonaws.com/fast-ai-imageclas/cifar10.tgz
# !tar -xf cifar10.tgz

# %%
# from image_dataset_loader import load
# (x_train, y_train), (x_test, y_test) = load('cifar10', ['train', 'test'])

# x_train = x_train.astype(numpy.float32)
# x_test  = x_test.astype(numpy.float32)

# x_train /= 255.
# x_test  /= 255.

# y_train = y_train.astype(numpy.int32)
# y_test  = y_test.astype(numpy.int32)

# print()
# print('CIFAR-10 data loaded: train:',len(x_train),'test:',len(x_test))
# print('X_train:', x_train.shape)
# print('y_train:', y_train.shape)

# %% [markdown]
# This time we won't flatten the images upfront.
#
# The training data (`X_train`) is a 3rd-order tensor of size (50000, 32, 32), i.e. it consists of 50000 images of size 32x32 pixels.
#
# `y_train` is a 50000-dimensional vector containing the correct classes ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') for each training sample.

# %% [markdown]
# <img src="images/image_representation.png"  align="left"/>

# %% [markdown]
# ## Linear model
#
# ### Initialization
#
# Let's begin with a simple linear model, but with the Keras library. First we use a `Flatten` layer to convert image data into vectors.
#
# A `Dense()` layer is a basic layer: $xW + b$ with an optional nonlinearity applied ("activation function"). The `Dense` layer connects each input to each output with some weight parameter. They are also called "fully connected."
#
# Here we add a `Dense` layer that has $32\times32\times3=3072$ input nodes (one for each pixel in the input image) and 10 output nodes.

# %%
class LinearClassifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)

        return x

# %% [markdown]
# We select *sparse categorical crossentropy* as the loss function, select [*stochastic gradient descent*](https://keras.io/optimizers/#sgd) as the optimizer, add *accuracy* to the list of metrics to be evaluated, and `compile()` the model. Note there are [several different options](https://keras.io/optimizers/) for the optimizer in Keras that we could use instead of *sgd*.

# %%
linear_model = LinearClassifier()

linear_model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=['accuracy'])
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-10-12 11:50:03.950041: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-12 11:50:03.950589: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Learning

# %% [markdown]
# Now we are ready to train our first model. An epoch means one pass through the whole training data.

# %% [markdown]
# Here is a concise way to train the network. The fit function handles looping over the batches. We'll see a more verbose approach in the next notebook that allows more performance tuning.

# %% [markdown]
# You can run the code below multiple times and it will continue the training process from where it left off. If you want to start from scratch, re-initialize the model using the code a few cells ago.

# %%
# %%time
# This took about a third of a second per epoch on my laptop
batch_size = 512
epochs = 30
history = linear_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/30
# 2022-10-12 11:50:47.663703: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-12 11:50:48.047999: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 98/98 - 3s - loss: 2.1516 - accuracy: 0.2187 - 3s/epoch - 26ms/step
# Epoch 2/30
# 98/98 - 1s - loss: 1.9948 - accuracy: 0.3005 - 571ms/epoch - 6ms/step
# Epoch 3/30
# 98/98 - 1s - loss: 1.9383 - accuracy: 0.3246 - 572ms/epoch - 6ms/step
# Epoch 4/30
# 98/98 - 1s - loss: 1.9042 - accuracy: 0.3396 - 566ms/epoch - 6ms/step
# Epoch 5/30
# 98/98 - 1s - loss: 1.8818 - accuracy: 0.3490 - 568ms/epoch - 6ms/step
# Epoch 6/30
# 98/98 - 1s - loss: 1.8646 - accuracy: 0.3540 - 573ms/epoch - 6ms/step
# Epoch 7/30
# 98/98 - 1s - loss: 1.8527 - accuracy: 0.3600 - 561ms/epoch - 6ms/step
# Epoch 8/30
# 98/98 - 1s - loss: 1.8412 - accuracy: 0.3647 - 567ms/epoch - 6ms/step
# Epoch 9/30
# 98/98 - 1s - loss: 1.8318 - accuracy: 0.3679 - 565ms/epoch - 6ms/step
# Epoch 10/30
# 98/98 - 1s - loss: 1.8237 - accuracy: 0.3702 - 563ms/epoch - 6ms/step
# Epoch 11/30
# 98/98 - 1s - loss: 1.8175 - accuracy: 0.3726 - 567ms/epoch - 6ms/step
# Epoch 12/30
# 98/98 - 1s - loss: 1.8109 - accuracy: 0.3767 - 566ms/epoch - 6ms/step
# Epoch 13/30
# 98/98 - 1s - loss: 1.8059 - accuracy: 0.3779 - 562ms/epoch - 6ms/step
# Epoch 14/30
# 98/98 - 1s - loss: 1.8018 - accuracy: 0.3789 - 564ms/epoch - 6ms/step
# Epoch 15/30
# 98/98 - 1s - loss: 1.7966 - accuracy: 0.3823 - 564ms/epoch - 6ms/step
# Epoch 16/30
# 98/98 - 1s - loss: 1.7925 - accuracy: 0.3821 - 566ms/epoch - 6ms/step
# Epoch 17/30
# 98/98 - 1s - loss: 1.7889 - accuracy: 0.3836 - 562ms/epoch - 6ms/step
# Epoch 18/30
# 98/98 - 1s - loss: 1.7852 - accuracy: 0.3864 - 558ms/epoch - 6ms/step
# Epoch 19/30
# 98/98 - 1s - loss: 1.7826 - accuracy: 0.3861 - 564ms/epoch - 6ms/step
# Epoch 20/30
# 98/98 - 1s - loss: 1.7795 - accuracy: 0.3878 - 574ms/epoch - 6ms/step
# Epoch 21/30
# 98/98 - 1s - loss: 1.7761 - accuracy: 0.3900 - 562ms/epoch - 6ms/step
# Epoch 22/30
# 98/98 - 1s - loss: 1.7735 - accuracy: 0.3912 - 557ms/epoch - 6ms/step
# Epoch 23/30
# 98/98 - 1s - loss: 1.7708 - accuracy: 0.3907 - 562ms/epoch - 6ms/step
# Epoch 24/30
# 98/98 - 1s - loss: 1.7685 - accuracy: 0.3934 - 566ms/epoch - 6ms/step
# Epoch 25/30
# 98/98 - 1s - loss: 1.7663 - accuracy: 0.3926 - 562ms/epoch - 6ms/step
# Epoch 26/30
# 98/98 - 1s - loss: 1.7638 - accuracy: 0.3956 - 566ms/epoch - 6ms/step
# Epoch 27/30
# 98/98 - 1s - loss: 1.7622 - accuracy: 0.3960 - 568ms/epoch - 6ms/step
# Epoch 28/30
# 98/98 - 1s - loss: 1.7599 - accuracy: 0.3961 - 567ms/epoch - 6ms/step
# Epoch 29/30
# 98/98 - 1s - loss: 1.7574 - accuracy: 0.3966 - 559ms/epoch - 6ms/step
# Epoch 30/30
# 98/98 - 1s - loss: 1.7550 - accuracy: 0.3979 - 564ms/epoch - 6ms/step
# CPU times: user 11.5 s, sys: 11.5 s, total: 23 s
# Wall time: 19.8 s

# %%
print(linear_model.summary())
# Out:
# Model: "linear_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  30730
#
# =================================================================
# Total params: 30,730
# Trainable params: 30,730
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# The summary shows that there are 30730 parameters in our model, as the weight matrix is of size 3072x10, plus there's a bias vector of 10x1.

# %% [markdown]
# Let's now see how the training progressed.
#
# * *Loss* is a function of the difference of the network output and the target values.  We are minimizing the loss function during training so it should decrease over time.
# * *Accuracy* is the classification accuracy for the training data (100*accuracy is the percentage labeled correctly), so it should increase over time
#
# Note that for either measure, we cannot fully trust the progress, as the model may have overfitted and just memorized the training data.

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %% [markdown]
# ### Inference
#
# For a better measure of the quality of the model, let's see the model accuracy for the test data.

# %%
linscores = linear_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (linear_model.metrics_names[1], linscores[1]*100))
# Out:
# 2022-10-12 11:52:24.240562: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 313/313 - 1s - loss: 1.7676 - accuracy: 0.3944 - 1s/epoch - 4ms/step
# accuracy: 39.44%

# %% [markdown]
# We can now take a closer look on the results.
#
# Let's define a helper function to show the failure cases of our classifier.

# %%
def show_failures(predictions, trueclass=None, predictedclass=None, maxtoshow=20):
    rounded = numpy.argmax(predictions, axis=1)
    errors = rounded!=y_test.flatten()
    print('Showing max', maxtoshow, 'first failures. '
          'The predicted class is shown first and the correct class in parenthesis.')
    ii = 0
    plt.figure(figsize=(maxtoshow, 1))
    for i in range(x_test.shape[0]):
        if ii>=maxtoshow:
            break
        if errors[i]:
            if trueclass is not None and y_test[i] != trueclass:
                continue
            if predictedclass is not None and rounded[i] != predictedclass:
                continue
            plt.subplot(1, maxtoshow, ii+1)
            plt.axis('off')
            plt.imshow(x_test[i,:,:], cmap="gray")
            plt.title("%d (%d)" % (rounded[i], y_test[i]))
            ii = ii + 1

# %% [markdown]
# Here are the first 20 test images the linear model classified to a wrong class:

# %%
linpredictions = linear_model.predict(x_test)

show_failures(linpredictions)
# Out:
#  78/313 [======>.......................] - ETA: 0s
# 2022-10-12 11:53:08.587844: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# ## Multi-layer perceptron (MLP) network
#
# ### Initialization
#
# Let's now create a more complex MLP model that has multiple layers, non-linear activation functions, and dropout layers.
#
# `Dropout()` randomly sets a fraction of inputs to zero during training, which is one approach to regularization and can sometimes help to prevent overfitting.
#
# There are two options below, a simple and a bit more complex model.  Select either one.
#
# The output of the last layer needs to be a softmaxed 10-dimensional vector to match the groundtruth (`y_train`).

# %%
class NonlinearClassifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(50, activation='relu')
        
        # A bit more complex model: (need to uncomment in call fn as well)
        self.layer_2 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_3 = tf.keras.layers.Dropout(0.2)
        self.layer_4 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_5 = tf.keras.layers.Dropout(0.2)
        
        # The last layer needs to be like this:
        self.layer_out = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)
        
        # The more complex version:
        x = self.layer_2(x)
        x = self.drop_3(x)
        x = self.layer_4(x)
        x = self.drop_5(x)
        
        x = self.layer_out(x)

        return x

# %% [markdown]
# Finally, we again `compile()` the model, this time using [*SGD*](https://keras.io/optimizers/#rmsprop) as the optimizer.

# %%
nonlinear_model = NonlinearClassifier()

nonlinear_model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# ### Learning

# %%
# %%time
# This took around a third of a second per epoch on my laptop for the simpler version, 
# and around 1 second per epoch for the more complex one.
batch_size = 512
epochs = 30
history = nonlinear_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/30
# 2022-10-12 11:55:10.417383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 98/98 - 2s - loss: 2.2973 - accuracy: 0.1315 - 2s/epoch - 19ms/step
# Epoch 2/30
# 98/98 - 1s - loss: 2.2591 - accuracy: 0.1666 - 656ms/epoch - 7ms/step
# Epoch 3/30
# 98/98 - 1s - loss: 2.2118 - accuracy: 0.1909 - 664ms/epoch - 7ms/step
# Epoch 4/30
# 98/98 - 1s - loss: 2.1608 - accuracy: 0.2106 - 660ms/epoch - 7ms/step
# Epoch 5/30
# 98/98 - 1s - loss: 2.1097 - accuracy: 0.2280 - 649ms/epoch - 7ms/step
# Epoch 6/30
# 98/98 - 1s - loss: 2.0708 - accuracy: 0.2416 - 649ms/epoch - 7ms/step
# Epoch 7/30
# 98/98 - 1s - loss: 2.0351 - accuracy: 0.2541 - 655ms/epoch - 7ms/step
# Epoch 8/30
# 98/98 - 1s - loss: 2.0101 - accuracy: 0.2673 - 658ms/epoch - 7ms/step
# Epoch 9/30
# 98/98 - 1s - loss: 1.9874 - accuracy: 0.2744 - 654ms/epoch - 7ms/step
# Epoch 10/30
# 98/98 - 1s - loss: 1.9688 - accuracy: 0.2817 - 654ms/epoch - 7ms/step
# Epoch 11/30
# 98/98 - 1s - loss: 1.9516 - accuracy: 0.2866 - 649ms/epoch - 7ms/step
# Epoch 12/30
# 98/98 - 1s - loss: 1.9370 - accuracy: 0.2944 - 664ms/epoch - 7ms/step
# Epoch 13/30
# 98/98 - 1s - loss: 1.9254 - accuracy: 0.2980 - 651ms/epoch - 7ms/step
# Epoch 14/30
# 98/98 - 1s - loss: 1.9114 - accuracy: 0.3048 - 659ms/epoch - 7ms/step
# Epoch 15/30
# 98/98 - 1s - loss: 1.9024 - accuracy: 0.3087 - 742ms/epoch - 8ms/step
# Epoch 16/30
# 98/98 - 1s - loss: 1.8918 - accuracy: 0.3134 - 713ms/epoch - 7ms/step
# Epoch 17/30
# 98/98 - 1s - loss: 1.8846 - accuracy: 0.3157 - 674ms/epoch - 7ms/step
# Epoch 18/30
# 98/98 - 1s - loss: 1.8750 - accuracy: 0.3189 - 654ms/epoch - 7ms/step
# Epoch 19/30
# 98/98 - 1s - loss: 1.8653 - accuracy: 0.3212 - 671ms/epoch - 7ms/step
# Epoch 20/30
# 98/98 - 1s - loss: 1.8607 - accuracy: 0.3292 - 659ms/epoch - 7ms/step
# Epoch 21/30
# 98/98 - 1s - loss: 1.8517 - accuracy: 0.3302 - 646ms/epoch - 7ms/step
# Epoch 22/30
# 98/98 - 1s - loss: 1.8421 - accuracy: 0.3334 - 646ms/epoch - 7ms/step
# Epoch 23/30
# 98/98 - 1s - loss: 1.8380 - accuracy: 0.3350 - 650ms/epoch - 7ms/step
# Epoch 24/30
# 98/98 - 1s - loss: 1.8296 - accuracy: 0.3388 - 659ms/epoch - 7ms/step
# Epoch 25/30
# 98/98 - 1s - loss: 1.8231 - accuracy: 0.3419 - 663ms/epoch - 7ms/step
# Epoch 26/30
# 98/98 - 1s - loss: 1.8150 - accuracy: 0.3457 - 664ms/epoch - 7ms/step
# Epoch 27/30
# 98/98 - 1s - loss: 1.8135 - accuracy: 0.3474 - 657ms/epoch - 7ms/step
# Epoch 28/30
# 98/98 - 1s - loss: 1.8077 - accuracy: 0.3523 - 618ms/epoch - 6ms/step
# Epoch 29/30
# 98/98 - 1s - loss: 1.8018 - accuracy: 0.3526 - 641ms/epoch - 7ms/step
# Epoch 30/30
# 98/98 - 1s - loss: 1.7896 - accuracy: 0.3568 - 653ms/epoch - 7ms/step
# CPU times: user 17.3 s, sys: 13.4 s, total: 30.7 s
# Wall time: 21.6 s

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %% [markdown]
# ### Inference
#
# Accuracy for test data.  The model should be better than the linear model.

# %%
# %%time
scores = nonlinear_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (nonlinear_model.metrics_names[1], scores[1]*100))
# Out:
# 2022-10-12 11:55:52.504591: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 313/313 - 2s - loss: 1.7241 - accuracy: 0.3956 - 2s/epoch - 5ms/step
# accuracy: 39.56%
# CPU times: user 1.11 s, sys: 895 ms, total: 2.01 s
# Wall time: 1.66 s

# %% [markdown]
# We can again take a closer look on the results, using the `show_failures()` function defined earlier.
#
# Here are the first 20 test images the MLP classified to a wrong class:

# %%
predictions = nonlinear_model.predict(x_test)

show_failures(predictions)
# Out:
#  55/313 [====>.........................] - ETA: 0s
# 2022-10-12 11:56:02.291305: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 3ms/step
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# We can use `show_failures()` to inspect failures in more detail. For example, here are failures in which the true class was "6":

# %%
show_failures(predictions, trueclass=6)
# Out:
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# We can also compute the confusion matrix to see which image get mixed the most, and look at classification accuracies separately for each class:

# %%
from sklearn.metrics import confusion_matrix

print('Confusion matrix (rows: true classes; columns: predicted classes):'); print()
cm=confusion_matrix(y_test, numpy.argmax(predictions, axis=1), labels=list(range(10)))
print(cm); print()

print('Classification accuracy for each class:'); print()
for i,j in enumerate(cm.diagonal()/cm.sum(axis=1)): print("%d: %.4f" % (i,j))
# Out:
# Confusion matrix (rows: true classes; columns: predicted classes):
#
# [[387  45  80  49  38  16  30  86 208  61]
#  [ 28 478  24  47  14  24  73  34  98 180]
#  [ 84  31 164  80 229  82 203  90  29   8]
#  [ 13  55  65 222  51 228 230  67  25  44]
#  [ 41  22  92  50 359  56 246  94  25  15]
#  [  9  23  63 140  75 370 183  87  30  20]
#  [  4  31  25  80 129  83 596  29   9  14]
#  [ 23  39  58  76 145  67 103 407  27  55]
#  [126  80  32  39  16  37  22  26 502 120]
#  [ 38 187   6  36  13  23  70  59  97 471]]
#
# Classification accuracy for each class:
#
# 0: 0.3870
# 1: 0.4780
# 2: 0.1640
# 3: 0.2220
# 4: 0.3590
# 5: 0.3700
# 6: 0.5960
# 7: 0.4070
# 8: 0.5020
# 9: 0.4710

# %% [markdown]
# In the next notebook, we'll introduce convolutional layers, which are commonly used for images.

# %% [markdown]
# # In-class exercise: improve the accuracy of this model

# %% [markdown]
# How can you improve model accuracy by increasing epochs, stacking more layers, or changing the optimizer?

# %% [markdown]
# As before, the model is not fully trained in the provided number of epochs. Dropping the batch size to 256 and running for 180 more epochs with the `adam` optimizer brings the nonlinear classifier up to 50.1% accuracy. To get a bit further, we could try to expand the network:
#  - the first layer can be made wider, with 150 inputs
#  - an additional dense layer of width 30 can be added before the output
# This doesn't lead to a significant gain in accuracy after 200 epochs.

# %%
class BetterClassifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(150, activation='relu')
        
        # A bit more complex model: (need to uncomment in call fn as well)
        self.layer_2 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_3 = tf.keras.layers.Dropout(0.2)
        self.layer_4 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_5 = tf.keras.layers.Dropout(0.2)
        self.layer_6 = tf.keras.layers.Dense(30, activation='relu')
        self.drop_7 = tf.keras.layers.Dropout(0.2)
        
        # The last layer needs to be like this:
        self.layer_out = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)
        
        # The more complex version:
        x = self.layer_2(x)
        x = self.drop_3(x)
        x = self.layer_4(x)
        x = self.drop_5(x)
        x = self.layer_6(x)
        x = self.drop_7(x)
        
        x = self.layer_out(x)

        return x

better_model = BetterClassifier()
better_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

# %%
batch_size = 512
epochs = 100
history = better_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/100
# 98/98 - 1s - loss: 1.3303 - accuracy: 0.5292 - 1s/epoch - 14ms/step
# Epoch 2/100
# 98/98 - 1s - loss: 1.3247 - accuracy: 0.5296 - 813ms/epoch - 8ms/step
# Epoch 3/100
# 98/98 - 1s - loss: 1.3235 - accuracy: 0.5315 - 788ms/epoch - 8ms/step
# Epoch 4/100
# 98/98 - 1s - loss: 1.3244 - accuracy: 0.5305 - 787ms/epoch - 8ms/step
# Epoch 5/100
# 98/98 - 1s - loss: 1.3238 - accuracy: 0.5293 - 787ms/epoch - 8ms/step
# Epoch 6/100
# 98/98 - 1s - loss: 1.3223 - accuracy: 0.5309 - 786ms/epoch - 8ms/step
# Epoch 7/100
# 98/98 - 1s - loss: 1.3146 - accuracy: 0.5331 - 795ms/epoch - 8ms/step
# Epoch 8/100
# 98/98 - 1s - loss: 1.3217 - accuracy: 0.5294 - 791ms/epoch - 8ms/step
# Epoch 9/100
# 98/98 - 1s - loss: 1.3171 - accuracy: 0.5339 - 791ms/epoch - 8ms/step
# Epoch 10/100
# 98/98 - 1s - loss: 1.3222 - accuracy: 0.5302 - 781ms/epoch - 8ms/step
# Epoch 11/100
# 98/98 - 1s - loss: 1.3165 - accuracy: 0.5334 - 783ms/epoch - 8ms/step
# Epoch 12/100
# 98/98 - 1s - loss: 1.3184 - accuracy: 0.5362 - 850ms/epoch - 9ms/step
# Epoch 13/100
# 98/98 - 1s - loss: 1.3129 - accuracy: 0.5363 - 880ms/epoch - 9ms/step
# Epoch 14/100
# 98/98 - 1s - loss: 1.3157 - accuracy: 0.5345 - 889ms/epoch - 9ms/step
# Epoch 15/100
# 98/98 - 1s - loss: 1.3135 - accuracy: 0.5373 - 797ms/epoch - 8ms/step
# Epoch 16/100
# 98/98 - 1s - loss: 1.3139 - accuracy: 0.5341 - 790ms/epoch - 8ms/step
# Epoch 17/100
# 98/98 - 1s - loss: 1.3145 - accuracy: 0.5344 - 791ms/epoch - 8ms/step
# Epoch 18/100
# 98/98 - 1s - loss: 1.3164 - accuracy: 0.5333 - 792ms/epoch - 8ms/step
# Epoch 19/100
# 98/98 - 1s - loss: 1.3100 - accuracy: 0.5373 - 834ms/epoch - 9ms/step
# Epoch 20/100
# 98/98 - 1s - loss: 1.3065 - accuracy: 0.5379 - 780ms/epoch - 8ms/step
# Epoch 21/100
# 98/98 - 1s - loss: 1.3144 - accuracy: 0.5330 - 793ms/epoch - 8ms/step
# Epoch 22/100
# 98/98 - 1s - loss: 1.3061 - accuracy: 0.5394 - 800ms/epoch - 8ms/step
# Epoch 23/100
# 98/98 - 1s - loss: 1.3037 - accuracy: 0.5381 - 783ms/epoch - 8ms/step
# Epoch 24/100
# 98/98 - 1s - loss: 1.3038 - accuracy: 0.5365 - 782ms/epoch - 8ms/step
# Epoch 25/100
# 98/98 - 1s - loss: 1.3107 - accuracy: 0.5377 - 788ms/epoch - 8ms/step
# Epoch 26/100
# 98/98 - 1s - loss: 1.3012 - accuracy: 0.5386 - 792ms/epoch - 8ms/step
# Epoch 27/100
# 98/98 - 1s - loss: 1.3037 - accuracy: 0.5386 - 781ms/epoch - 8ms/step
# Epoch 28/100
# 98/98 - 1s - loss: 1.2997 - accuracy: 0.5404 - 797ms/epoch - 8ms/step
# Epoch 29/100
# 98/98 - 1s - loss: 1.3039 - accuracy: 0.5392 - 787ms/epoch - 8ms/step
# Epoch 30/100
# 98/98 - 1s - loss: 1.3058 - accuracy: 0.5388 - 780ms/epoch - 8ms/step
# Epoch 31/100
# 98/98 - 1s - loss: 1.3020 - accuracy: 0.5384 - 791ms/epoch - 8ms/step
# Epoch 32/100
# 98/98 - 1s - loss: 1.2968 - accuracy: 0.5393 - 803ms/epoch - 8ms/step
# Epoch 33/100
# 98/98 - 1s - loss: 1.3010 - accuracy: 0.5405 - 796ms/epoch - 8ms/step
# Epoch 34/100
# 98/98 - 1s - loss: 1.2998 - accuracy: 0.5402 - 772ms/epoch - 8ms/step
# Epoch 35/100
# 98/98 - 1s - loss: 1.3030 - accuracy: 0.5395 - 767ms/epoch - 8ms/step
# Epoch 36/100
# 98/98 - 1s - loss: 1.2962 - accuracy: 0.5408 - 804ms/epoch - 8ms/step
# Epoch 37/100
# 98/98 - 1s - loss: 1.2925 - accuracy: 0.5438 - 789ms/epoch - 8ms/step
# Epoch 38/100
# 98/98 - 1s - loss: 1.3023 - accuracy: 0.5391 - 787ms/epoch - 8ms/step
# Epoch 39/100
# 98/98 - 1s - loss: 1.2890 - accuracy: 0.5431 - 801ms/epoch - 8ms/step
# Epoch 40/100
# 98/98 - 1s - loss: 1.2923 - accuracy: 0.5403 - 789ms/epoch - 8ms/step
# Epoch 41/100
# 98/98 - 1s - loss: 1.2928 - accuracy: 0.5425 - 795ms/epoch - 8ms/step
# Epoch 42/100
# 98/98 - 1s - loss: 1.2885 - accuracy: 0.5440 - 794ms/epoch - 8ms/step
# Epoch 43/100
# 98/98 - 1s - loss: 1.2888 - accuracy: 0.5417 - 826ms/epoch - 8ms/step
# Epoch 44/100
# 98/98 - 1s - loss: 1.2933 - accuracy: 0.5429 - 856ms/epoch - 9ms/step
# Epoch 45/100
# 98/98 - 1s - loss: 1.2924 - accuracy: 0.5415 - 900ms/epoch - 9ms/step
# Epoch 46/100
# 98/98 - 1s - loss: 1.2913 - accuracy: 0.5396 - 805ms/epoch - 8ms/step
# Epoch 47/100
# 98/98 - 1s - loss: 1.2904 - accuracy: 0.5422 - 1s/epoch - 11ms/step
# Epoch 48/100
# 98/98 - 1s - loss: 1.2906 - accuracy: 0.5439 - 844ms/epoch - 9ms/step
# Epoch 49/100
# 98/98 - 1s - loss: 1.2863 - accuracy: 0.5448 - 1s/epoch - 11ms/step
# Epoch 50/100
# 98/98 - 1s - loss: 1.2773 - accuracy: 0.5472 - 877ms/epoch - 9ms/step
# Epoch 51/100
# 98/98 - 1s - loss: 1.2798 - accuracy: 0.5466 - 937ms/epoch - 10ms/step
# Epoch 52/100
# 98/98 - 1s - loss: 1.2864 - accuracy: 0.5422 - 825ms/epoch - 8ms/step
# Epoch 53/100
# 98/98 - 1s - loss: 1.2868 - accuracy: 0.5445 - 916ms/epoch - 9ms/step
# Epoch 54/100
# 98/98 - 1s - loss: 1.2788 - accuracy: 0.5486 - 963ms/epoch - 10ms/step
# Epoch 55/100
# 98/98 - 1s - loss: 1.2781 - accuracy: 0.5477 - 836ms/epoch - 9ms/step
# Epoch 56/100
# 98/98 - 1s - loss: 1.2860 - accuracy: 0.5434 - 866ms/epoch - 9ms/step
# Epoch 57/100
# 98/98 - 1s - loss: 1.2820 - accuracy: 0.5499 - 791ms/epoch - 8ms/step
# Epoch 58/100
# 98/98 - 1s - loss: 1.2812 - accuracy: 0.5442 - 787ms/epoch - 8ms/step
# Epoch 59/100
# 98/98 - 1s - loss: 1.2855 - accuracy: 0.5468 - 779ms/epoch - 8ms/step
# Epoch 60/100
# 98/98 - 1s - loss: 1.2749 - accuracy: 0.5496 - 920ms/epoch - 9ms/step
# Epoch 61/100
# 98/98 - 1s - loss: 1.2752 - accuracy: 0.5491 - 909ms/epoch - 9ms/step
# Epoch 62/100
# 98/98 - 1s - loss: 1.2814 - accuracy: 0.5489 - 815ms/epoch - 8ms/step
# Epoch 63/100
# 98/98 - 1s - loss: 1.2828 - accuracy: 0.5474 - 859ms/epoch - 9ms/step
# Epoch 64/100
# 98/98 - 1s - loss: 1.2732 - accuracy: 0.5495 - 889ms/epoch - 9ms/step
# Epoch 65/100
# 98/98 - 1s - loss: 1.2749 - accuracy: 0.5488 - 891ms/epoch - 9ms/step
# Epoch 66/100
# 98/98 - 1s - loss: 1.2751 - accuracy: 0.5493 - 980ms/epoch - 10ms/step
# Epoch 67/100
# 98/98 - 1s - loss: 1.2731 - accuracy: 0.5513 - 944ms/epoch - 10ms/step
# Epoch 68/100
# 98/98 - 1s - loss: 1.2694 - accuracy: 0.5502 - 960ms/epoch - 10ms/step
# Epoch 69/100
# 98/98 - 1s - loss: 1.2737 - accuracy: 0.5498 - 1s/epoch - 11ms/step
# Epoch 70/100
# 98/98 - 1s - loss: 1.2652 - accuracy: 0.5534 - 1s/epoch - 11ms/step
# Epoch 71/100
# 98/98 - 1s - loss: 1.2803 - accuracy: 0.5463 - 1s/epoch - 13ms/step
# Epoch 72/100
# 98/98 - 1s - loss: 1.2804 - accuracy: 0.5456 - 963ms/epoch - 10ms/step
# Epoch 73/100
# 98/98 - 1s - loss: 1.2700 - accuracy: 0.5500 - 944ms/epoch - 10ms/step
# Epoch 74/100
# 98/98 - 1s - loss: 1.2662 - accuracy: 0.5533 - 841ms/epoch - 9ms/step
# Epoch 75/100
# 98/98 - 1s - loss: 1.2710 - accuracy: 0.5512 - 805ms/epoch - 8ms/step
# Epoch 76/100
# 98/98 - 1s - loss: 1.2755 - accuracy: 0.5488 - 790ms/epoch - 8ms/step
# Epoch 77/100
# 98/98 - 1s - loss: 1.2668 - accuracy: 0.5518 - 795ms/epoch - 8ms/step
# Epoch 78/100
# 98/98 - 1s - loss: 1.2672 - accuracy: 0.5504 - 791ms/epoch - 8ms/step
# Epoch 79/100
# 98/98 - 1s - loss: 1.2636 - accuracy: 0.5521 - 783ms/epoch - 8ms/step
# Epoch 80/100
# 98/98 - 1s - loss: 1.2716 - accuracy: 0.5504 - 783ms/epoch - 8ms/step
# Epoch 81/100
# 98/98 - 1s - loss: 1.2612 - accuracy: 0.5523 - 796ms/epoch - 8ms/step
# Epoch 82/100
# 98/98 - 1s - loss: 1.2681 - accuracy: 0.5509 - 841ms/epoch - 9ms/step
# Epoch 83/100
# 98/98 - 1s - loss: 1.2646 - accuracy: 0.5521 - 793ms/epoch - 8ms/step
# Epoch 84/100
# 98/98 - 1s - loss: 1.2613 - accuracy: 0.5551 - 779ms/epoch - 8ms/step
# Epoch 85/100
# 98/98 - 1s - loss: 1.2647 - accuracy: 0.5512 - 776ms/epoch - 8ms/step
# Epoch 86/100
# 98/98 - 1s - loss: 1.2637 - accuracy: 0.5542 - 770ms/epoch - 8ms/step
# Epoch 87/100
# 98/98 - 1s - loss: 1.2605 - accuracy: 0.5522 - 776ms/epoch - 8ms/step
# Epoch 88/100
# 98/98 - 1s - loss: 1.2596 - accuracy: 0.5512 - 785ms/epoch - 8ms/step
# Epoch 89/100
# 98/98 - 1s - loss: 1.2640 - accuracy: 0.5517 - 790ms/epoch - 8ms/step
# Epoch 90/100
# 98/98 - 1s - loss: 1.2815 - accuracy: 0.5466 - 791ms/epoch - 8ms/step
# Epoch 91/100
# 98/98 - 1s - loss: 1.2503 - accuracy: 0.5566 - 790ms/epoch - 8ms/step
# Epoch 92/100
# 98/98 - 1s - loss: 1.2545 - accuracy: 0.5546 - 807ms/epoch - 8ms/step
# Epoch 93/100
# 98/98 - 1s - loss: 1.2677 - accuracy: 0.5535 - 787ms/epoch - 8ms/step
# Epoch 94/100
# 98/98 - 1s - loss: 1.2618 - accuracy: 0.5523 - 780ms/epoch - 8ms/step
# Epoch 95/100
# 98/98 - 1s - loss: 1.2608 - accuracy: 0.5557 - 781ms/epoch - 8ms/step
# Epoch 96/100
# 98/98 - 1s - loss: 1.2493 - accuracy: 0.5581 - 779ms/epoch - 8ms/step
# Epoch 97/100
# 98/98 - 1s - loss: 1.2504 - accuracy: 0.5597 - 787ms/epoch - 8ms/step
# Epoch 98/100
# 98/98 - 1s - loss: 1.2459 - accuracy: 0.5597 - 805ms/epoch - 8ms/step
# Epoch 99/100
# 98/98 - 1s - loss: 1.2509 - accuracy: 0.5581 - 777ms/epoch - 8ms/step
# Epoch 100/100
# 98/98 - 1s - loss: 1.2515 - accuracy: 0.5560 - 789ms/epoch - 8ms/step

# %%
scores = nonlinear_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (nonlinear_model.metrics_names[1], scores[1]*100))
# Out:
# 313/313 - 1s - loss: 1.4509 - accuracy: 0.4897 - 1s/epoch - 5ms/step
# accuracy: 48.97%
